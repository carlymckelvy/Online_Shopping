# %%
import pandas as pd
import itertools as it
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np

# %%
test = pd.read_csv("training_sample.csv")
sim_df = pd.DataFrame(columns=test.columns, index=test.columns)

# %%
from scipy.spatial import distance
for col_pair in it.combinations(test.columns, 2):
    sim_df.loc[col_pair] = sim_df.loc[tuple(reversed(col_pair))] = distance.jaccard(test[col_pair[0]], test[col_pair[1]])

# %%
sim_df
# Out:
#                         UserID basket_icon_click basket_add_list  \
# UserID                     NaN                 1               1
# basket_icon_click            1               NaN        0.660513
# basket_add_list              1          0.660513             NaN
# basket_add_detail            1          0.593206        0.756081
# sort_by                      1           0.93945        0.922269
# image_picker                 1          0.944255        0.952452
# account_page_click           1          0.986436        0.990691
# promo_banner_click           1          0.947699        0.948892
# detail_wishlist_add          1          0.988884        0.992801
# list_size_dropdown           1          0.779474        0.706948
# closed_minibasket_click      1          0.859665        0.899173
# checked_delivery_detail      1           0.71768        0.813839
# checked_returns_detail       1          0.973235        0.982407
# sign_in                      1          0.642352         0.77548
# saw_checkout                 1          0.663217        0.786634
# saw_sizecharts               1          0.999095        0.999325
# saw_delivery                 1          0.983259        0.987307
# saw_account_upgrade          1          0.995865        0.996825
# saw_homepage                 1          0.830875        0.865955
# device_mobile                1          0.901776        0.931191
# device_computer              1          0.930559        0.935847
# device_tablet                1          0.943704        0.943066
# returning_user               1          0.872072        0.915689
# loc_uk                       1          0.899931        0.924461
# ordered                      1          0.732045        0.813965
#
#                         basket_add_detail   sort_by image_picker  \
# UserID                                  1         1            1
# basket_icon_click                0.593206   0.93945     0.944255
# basket_add_list                  0.756081  0.922269     0.952452
# basket_add_detail                     NaN  0.933945     0.928152
# sort_by                          0.933945       NaN     0.883646
# image_picker                     0.928152  0.883646          NaN
# account_page_click                0.99037  0.999456      0.99913
# promo_banner_click               0.949665  0.961221     0.966549
# detail_wishlist_add              0.988303  0.990054     0.984218
# list_size_dropdown               0.792649  0.926279     0.954308
# closed_minibasket_click          0.906573   0.97471     0.977294
# checked_delivery_detail          0.722859  0.946726     0.937458
# checked_returns_detail           0.968174   0.98366     0.963758
# sign_in                           0.65636  0.946191     0.947283
# saw_checkout                     0.666429  0.947693     0.948263
# saw_sizecharts                   0.999166  0.998997     0.998946
# saw_delivery                      0.98489  0.985709     0.983542
# saw_account_upgrade              0.996676  0.996923     0.997231
# saw_homepage                     0.832191  0.929079     0.956442
# device_mobile                    0.897032  0.999075     0.999314
# device_computer                  0.907377  0.866311     0.897101
# device_tablet                    0.936981  0.937961     0.958675
# returning_user                   0.879815  0.962464     0.973558
# loc_uk                           0.885091  0.965906     0.975155
# ordered                          0.749468  0.952003     0.947383
#
#                         account_page_click promo_banner_click  \
# UserID                                   1                  1
# basket_icon_click                 0.986436           0.947699
# basket_add_list                   0.990691           0.948892
# basket_add_detail                  0.99037           0.949665
# sort_by                           0.999456           0.961221
# image_picker                       0.99913           0.966549
# account_page_click                     NaN            0.99149
# promo_banner_click                 0.99149                NaN
# detail_wishlist_add               0.991557           0.984852
# list_size_dropdown                 0.99464           0.962362
# closed_minibasket_click           0.984273             0.9623
# checked_delivery_detail           0.981933           0.960695
# checked_returns_detail            0.982475           0.980781
# sign_in                           0.960542           0.959738
# saw_checkout                      0.980519           0.961148
# saw_sizecharts                    0.997219            0.99947
# saw_delivery                      0.973788           0.985039
# saw_account_upgrade               0.987613           0.994641
# saw_homepage                      0.989586            0.97003
# device_mobile                     0.994855           0.986728
# device_computer                   0.999511           0.976153
# device_tablet                       0.9991           0.983024
# returning_user                    0.995519           0.981751
# loc_uk                            0.996453           0.984456
# ordered                           0.981317           0.962333
#
#                         detail_wishlist_add list_size_dropdown  ...  \
# UserID                                    1                  1  ...
# basket_icon_click                  0.988884           0.779474  ...
# basket_add_list                    0.992801           0.706948  ...
# basket_add_detail                  0.988303           0.792649  ...
# sort_by                            0.990054           0.926279  ...
# image_picker                       0.984218           0.954308  ...
# account_page_click                 0.991557            0.99464  ...
# promo_banner_click                 0.984852           0.962362  ...
# detail_wishlist_add                     NaN           0.992384  ...
# list_size_dropdown                 0.992384                NaN  ...
# closed_minibasket_click            0.985534           0.950413  ...
# checked_delivery_detail            0.988084            0.88596  ...
# checked_returns_detail             0.984715           0.986105  ...
# sign_in                            0.972104           0.853147  ...
# saw_checkout                       0.986314           0.865846  ...
# saw_sizecharts                     0.999437           0.999572  ...
# saw_delivery                       0.991192           0.990775  ...
# saw_account_upgrade                0.995692           0.997947  ...
# saw_homepage                       0.993419           0.726324  ...
# device_mobile                       0.99689           0.794922  ...
# device_computer                    0.994809           0.888324  ...
# device_tablet                      0.996256            0.89301  ...
# returning_user                     0.995773           0.767713  ...
# loc_uk                             0.996663           0.773688  ...
# ordered                            0.990536           0.908931  ...
#
#                         saw_sizecharts saw_delivery saw_account_upgrade  \
# UserID                               1            1                   1
# basket_icon_click             0.999095     0.983259            0.995865
# basket_add_list               0.999325     0.987307            0.996825
# basket_add_detail             0.999166      0.98489            0.996676
# sort_by                       0.998997     0.985709            0.996923
# image_picker                  0.998946     0.983542            0.997231
# account_page_click            0.997219     0.973788            0.987613
# promo_banner_click             0.99947     0.985039            0.994641
# detail_wishlist_add           0.999437     0.991192            0.995692
# list_size_dropdown            0.999572     0.990775            0.997947
# closed_minibasket_click        0.99888     0.986344             0.99604
# checked_delivery_detail       0.998749     0.937528            0.994165
# checked_returns_detail         0.99562     0.966389            0.992029
# sign_in                       0.999014     0.979334            0.994696
# saw_checkout                  0.998935     0.981641            0.994643
# saw_sizecharts                     NaN     0.997029            0.995542
# saw_delivery                  0.997029          NaN            0.982497
# saw_account_upgrade           0.995542     0.982497                 NaN
# saw_homepage                  0.999614     0.990172            0.997823
# device_mobile                 0.999726     0.995691            0.999075
# device_computer               0.999142     0.990804            0.998277
# device_tablet                 0.999659     0.993746             0.99876
# returning_user                0.999737     0.994435            0.998687
# loc_uk                        0.999661     0.994872            0.998932
# ordered                       0.998909     0.985022            0.994921
#
#                         saw_homepage device_mobile device_computer  \
# UserID                             1             1               1
# basket_icon_click           0.830875      0.901776        0.930559
# basket_add_list             0.865955      0.931191        0.935847
# basket_add_detail           0.832191      0.897032        0.907377
# sort_by                     0.929079      0.999075        0.866311
# image_picker                0.956442      0.999314        0.897101
# account_page_click          0.989586      0.994855        0.999511
# promo_banner_click           0.97003      0.986728        0.976153
# detail_wishlist_add         0.993419       0.99689        0.994809
# list_size_dropdown          0.726324      0.794922        0.888324
# closed_minibasket_click     0.967858      0.982913        0.990906
# checked_delivery_detail     0.891884      0.947046        0.925754
# checked_returns_detail       0.98604      0.992751        0.985232
# sign_in                     0.844367      0.921424        0.914301
# saw_checkout                0.857092      0.929924         0.91816
# saw_sizecharts              0.999614      0.999726        0.999142
# saw_delivery                0.990172      0.995691        0.990804
# saw_account_upgrade         0.997823      0.999075        0.998277
# saw_homepage                     NaN      0.762257        0.829889
# device_mobile               0.762257           NaN        0.997855
# device_computer             0.829889      0.997855             NaN
# device_tablet               0.906322      0.998652        0.998841
# returning_user              0.736779      0.552148        0.854589
# loc_uk                      0.726262      0.333141        0.827318
# ordered                     0.913212      0.964862        0.946255
#
#                         device_tablet returning_user    loc_uk   ordered
# UserID                              1              1         1         1
# basket_icon_click            0.943704       0.872072  0.899931  0.732045
# basket_add_list              0.943066       0.915689  0.924461  0.813965
# basket_add_detail            0.936981       0.879815  0.885091  0.749468
# sort_by                      0.937961       0.962464  0.965906  0.952003
# image_picker                 0.958675       0.973558  0.975155  0.947383
# account_page_click             0.9991       0.995519  0.996453  0.981317
# promo_banner_click           0.983024       0.981751  0.984456  0.962333
# detail_wishlist_add          0.996256       0.995773  0.996663  0.990536
# list_size_dropdown            0.89301       0.767713  0.773688  0.908931
# closed_minibasket_click      0.971913       0.976503    0.9822  0.920091
# checked_delivery_detail      0.950356       0.931334  0.935962  0.344572
# checked_returns_detail       0.989856       0.991772  0.990917  0.969309
# sign_in                      0.938922       0.895407  0.910527  0.532161
# saw_checkout                 0.941504       0.904167  0.919012  0.476488
# saw_sizecharts               0.999659       0.999737  0.999661  0.998909
# saw_delivery                 0.993746       0.994435  0.994872  0.985022
# saw_account_upgrade           0.99876       0.998687  0.998932  0.994921
# saw_homepage                 0.906322       0.736779  0.726262  0.913212
# device_mobile                0.998652       0.552148  0.333141  0.964862
# device_computer              0.998841       0.854589  0.827318  0.946255
# device_tablet                     NaN       0.884415  0.867318  0.960205
# returning_user               0.884415            NaN  0.483936  0.948113
# loc_uk                       0.867318       0.483936       NaN  0.956435
# ordered                      0.960205       0.948113  0.956435       NaN
#
# [25 rows x 25 columns]

# %%
# sim_df.to_csv(r'correlation.csv', index = True)

# %%
dropped = sim_df.drop(['UserID'])
dropped = dropped.drop(['UserID'], axis=1)

# %%
nareplaced = dropped.fillna(1)

# %%
heatmap = sn.heatmap(nareplaced, xticklabels=True, yticklabels=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':15}
#                   , pad=12
                 );

# %%
figure_1 = heatmap.get_figure()    
figure_1.savefig('Jaccard Correlation Heatmap.png')

# %%
# Only focused on correlation of web usage for users who've actually ordered.

# %%
ordered_test = pd.read_csv("training_sample_ordered_only.csv")
o_sim_df = pd.DataFrame(columns=ordered_test.columns, index=ordered_test.columns)

# %%
from scipy.spatial import distance
for col_pair in it.combinations(ordered_test.columns, 2):
    o_sim_df.loc[col_pair] = o_sim_df.loc[tuple(reversed(col_pair))] = distance.jaccard(ordered_test[col_pair[0]], ordered_test[col_pair[1]])
o_sim_df
# Out:
#                         UserID basket_icon_click basket_add_list  \
# UserID                     NaN                 1               1
# basket_icon_click            1               NaN        0.534569
# basket_add_list              1          0.534569             NaN
# basket_add_detail            1          0.431435        0.681025
# sort_by                      1          0.905902        0.879275
# image_picker                 1          0.921191        0.925394
# account_page_click           1          0.977434        0.977668
# promo_banner_click           1          0.939142        0.934917
# detail_wishlist_add          1           0.98921        0.990991
# list_size_dropdown           1          0.445289        0.313945
# closed_minibasket_click      1          0.861363        0.859434
# checked_delivery_detail      1          0.293499        0.566477
# checked_returns_detail       1          0.963764        0.970407
# sign_in                      1          0.288396        0.563171
# saw_checkout                 1          0.288902        0.564343
# saw_sizecharts               1          0.998748        0.998799
# saw_delivery                 1          0.981456        0.982326
# saw_account_upgrade          1          0.994116        0.993784
# saw_homepage                 1          0.443156        0.588243
# device_mobile                1          0.471591         0.67916
# device_computer              1          0.789022        0.788254
# device_tablet                1          0.851121        0.847191
# returning_user               1          0.437555        0.647769
# loc_uk                       1          0.305761        0.570828
# ordered                      1          0.288902        0.564343
#
#                         basket_add_detail   sort_by image_picker  \
# UserID                                  1         1            1
# basket_icon_click                0.431435  0.905902     0.921191
# basket_add_list                  0.681025  0.879275     0.925394
# basket_add_detail                     NaN  0.907668     0.903334
# sort_by                          0.907668       NaN     0.834606
# image_picker                     0.903334  0.834606          NaN
# account_page_click               0.980606  0.997025     0.996902
# promo_banner_click                0.94238  0.947879     0.953131
# detail_wishlist_add              0.988559  0.986203     0.981449
# list_size_dropdown               0.557801  0.890256     0.918966
# closed_minibasket_click          0.884908  0.952792     0.964494
# checked_delivery_detail          0.263318   0.91397     0.918314
# checked_returns_detail           0.954792  0.957608     0.929283
# sign_in                          0.258012  0.913417     0.917918
# saw_checkout                     0.260095  0.913948     0.918138
# saw_sizecharts                   0.998726  0.998194     0.998736
# saw_delivery                     0.982103  0.969538     0.972146
# saw_account_upgrade                0.9947  0.990145     0.992116
# saw_homepage                     0.473074  0.897242     0.908414
# device_mobile                    0.516768  0.991262     0.992324
# device_computer                  0.728805  0.796962     0.789211
# device_tablet                    0.859269   0.89052     0.916547
# returning_user                   0.500941  0.922594     0.930392
# loc_uk                           0.275472  0.917449     0.920524
# ordered                          0.260095  0.913948     0.918138
#
#                         account_page_click promo_banner_click  \
# UserID                                   1                  1
# basket_icon_click                 0.977434           0.939142
# basket_add_list                   0.977668           0.934917
# basket_add_detail                 0.980606            0.94238
# sort_by                           0.997025           0.947879
# image_picker                      0.996902           0.953131
# account_page_click                     NaN           0.981777
# promo_banner_click                0.981777                NaN
# detail_wishlist_add               0.989437            0.97878
# list_size_dropdown                0.976731           0.937835
# closed_minibasket_click           0.969631           0.940122
# checked_delivery_detail           0.979944            0.94981
# checked_returns_detail            0.981007           0.968828
# sign_in                           0.980028           0.949523
# saw_checkout                      0.980097           0.949667
# saw_sizecharts                    0.994987           0.998981
# saw_delivery                      0.979562           0.985737
# saw_account_upgrade               0.985169           0.994307
# saw_homepage                      0.970654           0.943413
# device_mobile                     0.966816           0.953236
# device_computer                   0.996578           0.951529
# device_tablet                     0.994595            0.95893
# returning_user                    0.980665           0.950064
# loc_uk                            0.979998           0.950428
# ordered                           0.980097           0.949667
#
#                         detail_wishlist_add list_size_dropdown  ...  \
# UserID                                    1                  1  ...
# basket_icon_click                   0.98921           0.445289  ...
# basket_add_list                    0.990991           0.313945  ...
# basket_add_detail                  0.988559           0.557801  ...
# sort_by                            0.986203           0.890256  ...
# image_picker                       0.981449           0.918966  ...
# account_page_click                 0.989437           0.976731  ...
# promo_banner_click                  0.97878           0.937835  ...
# detail_wishlist_add                     NaN           0.988779  ...
# list_size_dropdown                 0.988779                NaN  ...
# closed_minibasket_click            0.987043           0.857896  ...
# checked_delivery_detail            0.989894           0.459683  ...
# checked_returns_detail             0.978111           0.965914  ...
# sign_in                             0.98983           0.456932  ...
# saw_checkout                       0.989839           0.457917  ...
# saw_sizecharts                     0.995327           0.998938  ...
# saw_delivery                       0.996086           0.981674  ...
# saw_account_upgrade                0.996575           0.994031  ...
# saw_homepage                       0.988204           0.513623  ...
# device_mobile                      0.990406           0.593858  ...
# device_computer                    0.986617            0.80047  ...
# device_tablet                      0.992673           0.836653  ...
# returning_user                     0.989862           0.560435  ...
# loc_uk                              0.99008           0.466695  ...
# ordered                            0.989839           0.457917  ...
#
#                         saw_sizecharts saw_delivery saw_account_upgrade  \
# UserID                               1            1                   1
# basket_icon_click             0.998748     0.981456            0.994116
# basket_add_list               0.998799     0.982326            0.993784
# basket_add_detail             0.998726     0.982103              0.9947
# sort_by                       0.998194     0.969538            0.990145
# image_picker                  0.998736     0.972146            0.992116
# account_page_click            0.994987     0.979562            0.985169
# promo_banner_click            0.998981     0.985737            0.994307
# detail_wishlist_add           0.995327     0.996086            0.996575
# list_size_dropdown            0.998938     0.981674            0.994031
# closed_minibasket_click        0.99851     0.980167            0.995683
# checked_delivery_detail       0.998889      0.98328            0.994761
# checked_returns_detail        0.992948     0.945833            0.985915
# sign_in                       0.998893     0.983243            0.994783
# saw_checkout                    0.9989     0.983292            0.994815
# saw_sizecharts                     NaN            1            0.991597
# saw_delivery                         1          NaN            0.977995
# saw_account_upgrade           0.991597     0.977995                 NaN
# saw_homepage                  0.999255     0.979913            0.993217
# device_mobile                 0.999016     0.987665            0.995633
# device_computer               0.998363     0.976367            0.993693
# device_tablet                  0.99933     0.983297            0.992113
# returning_user                0.998997     0.984007            0.994533
# loc_uk                        0.998921     0.984218            0.994823
# ordered                         0.9989     0.983292            0.994815
#
#                         saw_homepage device_mobile device_computer  \
# UserID                             1             1               1
# basket_icon_click           0.443156      0.471591        0.789022
# basket_add_list             0.588243       0.67916        0.788254
# basket_add_detail           0.473074      0.516768        0.728805
# sort_by                     0.897242      0.991262        0.796962
# image_picker                0.908414      0.992324        0.789211
# account_page_click          0.970654      0.966816        0.996578
# promo_banner_click          0.943413      0.953236        0.951529
# detail_wishlist_add         0.988204      0.990406        0.986617
# list_size_dropdown          0.513623      0.593858         0.80047
# closed_minibasket_click     0.889126      0.878057        0.970264
# checked_delivery_detail     0.371048      0.418192        0.713743
# checked_returns_detail      0.963712        0.9713         0.95589
# sign_in                     0.368557        0.4164        0.713662
# saw_checkout                0.367726      0.414916        0.712722
# saw_sizecharts              0.999255      0.999016        0.998363
# saw_delivery                0.979913      0.987665        0.976367
# saw_account_upgrade         0.993217      0.995633        0.993693
# saw_homepage                     NaN      0.572034        0.737633
# device_mobile               0.572034           NaN        0.980786
# device_computer             0.737633      0.980786             NaN
# device_tablet               0.851996      0.988699         0.99201
# returning_user              0.513658      0.516781        0.773247
# loc_uk                      0.382424      0.416227        0.725585
# ordered                     0.367726      0.414916        0.712722
#
#                         device_tablet returning_user     loc_uk    ordered
# UserID                              1              1          1          1
# basket_icon_click            0.851121       0.437555   0.305761   0.288902
# basket_add_list              0.847191       0.647769   0.570828   0.564343
# basket_add_detail            0.859269       0.500941   0.275472   0.260095
# sort_by                       0.89052       0.922594   0.917449   0.913948
# image_picker                 0.916547       0.930392   0.920524   0.918138
# account_page_click           0.994595       0.980665   0.979998   0.980097
# promo_banner_click            0.95893       0.950064   0.950428   0.949667
# detail_wishlist_add          0.992673       0.989862    0.99008   0.989839
# list_size_dropdown           0.836653       0.560435   0.466695   0.457917
# closed_minibasket_click      0.906828       0.896946   0.894595   0.895511
# checked_delivery_detail      0.844886       0.327874  0.0378951  0.0103179
# checked_returns_detail       0.964649       0.972063   0.963905   0.963704
# sign_in                      0.844566       0.326573  0.0344231  0.0061279
# saw_checkout                  0.84455       0.321322  0.0290159          0
# saw_sizecharts                0.99933       0.998997   0.998921     0.9989
# saw_delivery                 0.983297       0.984007   0.984218   0.983292
# saw_account_upgrade          0.992113       0.994533   0.994823   0.994815
# saw_homepage                 0.851996       0.513658   0.382424   0.367726
# device_mobile                0.988699       0.516781   0.416227   0.414916
# device_computer               0.99201       0.773247   0.725585   0.712722
# device_tablet                     NaN       0.856219   0.843399    0.84455
# returning_user               0.856219            NaN   0.336309   0.321322
# loc_uk                       0.843399       0.336309        NaN  0.0290159
# ordered                       0.84455       0.321322  0.0290159        NaN
#
# [25 rows x 25 columns]

# %%
o_dropped = o_sim_df.drop(['UserID', 'ordered'])
o_dropped = o_dropped.drop(['UserID','ordered'], axis=1)

# %%
o_nareplaced = o_dropped.fillna(1)

# %%
o_heatmap = sn.heatmap(o_nareplaced, xticklabels=True, yticklabels=True)
o_heatmap.set_title('Ordered Only Correlation Heatmap', fontdict={'fontsize':15}, pad=12);

# %%
figure_2 = o_heatmap.get_figure()    
figure_2.savefig('Jaccard Ordered Only Correlation Heatmap.png')
